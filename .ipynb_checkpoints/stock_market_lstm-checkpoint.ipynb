# %% [markdown]
# ### Step 1: Importing all the necessary libraries and tools

# %%
import numpy as np
import math
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

# %%
df=pd.read_csv('stock_data.csv')

# %%
df['Date']=pd.to_datetime(df['Date'],format='%m/%d/%Y')
df['Date']=df['Date'].dt.strftime('%Y/%m/%d')

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018/10/08  208.00  222.25  206.85  216.00  215.15               4642146
# 1  2018/10/05  217.00  218.60  205.90  210.25  209.20               3519515
# 2  2018/10/04  223.50  227.80  216.15  217.25  218.20               1728786
# 3  2018/10/03  230.00  237.50  225.75  226.45  227.60               1708590
# 4  2018/10/01  234.55  234.60  221.05  230.30  230.90               1534749
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %% [markdown]
# ### Step 2: Visualizing the stock prices history

# %%
plt.figure(figsize=(15,8))
plt.title('Stock Prices History')
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Prices ($)')
# Out:
# Text(0, 0.5, 'Prices ($)')

# %% [markdown]
# ### 3. Data Preprocessing
# 1. Seperating data into a training set and a test set
# 2. Normalizing data so that all values are ranged from 0 to 1

# %%
close_prices=df['Close']
values=close_prices.values
training_data_len=math.ceil(len(values)*0.8)

scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(values.reshape(-1,1))

train_data=scaled_data[0: training_data_len, :]

x_train=[]
y_train=[]

for i in range(60,len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
    
x_train,y_train=np.array(x_train),np.array(y_train)

x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
